# %%
import re

# %% [markdown]
# # Formatting stata output

# %%
raw_table =\
r'''Tone Sentiment\_{1}&       0.241\sym{**} &       0.138         &      -0.277\sym{*}  &      0.0405         &      0.0732         \\
            &     (0.113)         &     (0.148)         &     (0.161)         &    (0.0265)         &    (0.0515)         \\
[1em]
Tone Sentiment\_{2}&      -0.248         &      -0.222         &      -0.352         &      -0.153         &      0.0448         \\
            &     (0.160)         &     (0.228)         &     (0.217)         &    (0.0915)         &     (0.114)         \\
[1em]
Rate Change &       6.904         &       7.934         &      -2.356         &      -1.534\sym{**} &       1.673         \\
			&     (4.112)         &     (4.768)         &     (3.059)         &     (0.663)         &     (2.195)         \\
[1em]
Rate Change##Tone Sentiment\_{1}&       0.109         &      -0.446         &       0.244         &      -0.139\sym{*}  &       0.114         \\
            &     (0.302)         &     (0.412)         &     (0.272)         &    (0.0759)         &     (0.196)         \\
[1em]
Rate Change##Tone Sentiment\_{2}&       1.007\sym{**} &       2.132\sym{***}&      -0.771\sym{**} &     0.00614         &       0.113         \\
            &     (0.460)         &     (0.543)         &     (0.309)         &    (0.0964)         &     (0.301)         \\
[1em]
Transparency&       0.137         &     -0.0255         &      -0.313\sym{*}  &      0.0689         &      0.0847         \\
            &     (0.170)         &     (0.222)         &     (0.154)         &    (0.0486)         &    (0.0870)         \\
[1em]
Trust       &      -2.008         &      -4.149         &      -7.424         &       0.560         &      -0.920         \\
            &     (2.992)         &     (4.537)         &     (5.338)         &     (0.668)         &     (1.287)         \\
'''
res = re.sub("[ ]+", "  ", raw_table)[:-1]
res = res.replace("  &  RUABITR  &  &  &  & ", 
                  "  & \multicolumn{5}{c}{RUABITR}")
res = res.replace("Tone  ", "Tone ")
res = res.replace("Rate  ", "Rate ")
res = res.replace("\(N\)", "\(Number\;of\;obs.\)")
res = res.replace("\hline\hline\n\\", "\hline\n\\")
res = res.replace("\\_", "_")
res = res.replace("\\multicolumn{6}{l}", "%\\multicolumn{6}{l}")
print(res)
# Out:
# Tone Sentiment_{1}&  0.241\sym{**}  &  0.138  &  -0.277\sym{*}  &  0.0405  &  0.0732  \\
#   &  (0.113)  &  (0.148)  &  (0.161)  &  (0.0265)  &  (0.0515)  \\
# [1em]
# Tone Sentiment_{2}&  -0.248  &  -0.222  &  -0.352  &  -0.153  &  0.0448  \\
#   &  (0.160)  &  (0.228)  &  (0.217)  &  (0.0915)  &  (0.114)  \\
# [1em]
# Rate Change  &  6.904  &  7.934  &  -2.356  &  -1.534\sym{**}  &  1.673  \\
# 			&  (4.112)  &  (4.768)  &  (3.059)  &  (0.663)  &  (2.195)  \\
# [1em]
# Rate Change##Tone Sentiment_{1}&  0.109  &  -0.446  &  0.244  &  -0.139\sym{*}  &  0.114  \\
#   &  (0.302)  &  (0.412)  &  (0.272)  &  (0.0759)  &  (0.196)  \\
# [1em]
# Rate Change##Tone Sentiment_{2}&  1.007\sym{**}  &  2.132\sym{***}&  -0.771\sym{**}  &  0.00614  &  0.113  \\
#   &  (0.460)  &  (0.543)  &  (0.309)  &  (0.0964)  &  (0.301)  \\
# [1em]
# Transparency&  0.137  &  -0.0255  &  -0.313\sym{*}  &  0.0689  &  0.0847  \\
#   &  (0.170)  &  (0.222)  &  (0.154)  &  (0.0486)  &  (0.0870)  \\
# [1em]
# ...

# %%
# &  \multicolumn{3}{c}{Tone Sentiment_{1}}  \\

raw_table =\
r'''    \begin{tabular}{l*{3}{c}}
    \hline\hline
                & \multicolumn{3}{c}{Tone Sentiment_{1}} \\
                &\multicolumn{1}{c}{(1)}         &\multicolumn{1}{c}{(2)}         &\multicolumn{1}{c}{(3)}         \\
    \hline
    Tone Sentiment_{2}      &      0.0881         &     -0.0976         &       16.04         \\
                &     (0.178)         &     (2.862)         &     (33.07)         \\
    [1em]
    Tone Sentiment_{2}^2     &                     &      -0.695         &       121.0         \\
                &                     &     (10.69)         &     (248.7)         \\
    [1em]
    Tone Sentiment_{2}^3     &                     &                     &       303.1         \\
                &                     &                     &     (618.7)         \\
    \hline
    \(Number\;of\;obs.\)      &          40         &          40         &          40         \\
    \hline
    \end{tabular}
'''
res = re.sub("[ ]+", "  ", raw_table)[:-1]
res = res.replace("tonepr", "Tone Sentiment_{2}")
res = res.replace("tonepr2", "Tone Sentiment_{2}^2")
res = res.replace("tonepr3", "Tone Sentiment_{2}^3")
res = res.replace("Tone  ", "Tone ")
res = res.replace("\(N\)", "\(Number\;of\;obs.\)")
res = res.replace("\\_", "_")
print(res)
# Out:
#   \begin{tabular}{l*{3}{c}}
#   \hline\hline
#   &  \multicolumn{3}{c}{Tone Sentiment_{1}}  \\
#   &\multicolumn{1}{c}{(1)}  &\multicolumn{1}{c}{(2)}  &\multicolumn{1}{c}{(3)}  \\
#   \hline
#   Tone Sentiment_{2}  &  0.0881  &  -0.0976  &  16.04  \\
#   &  (0.178)  &  (2.862)  &  (33.07)  \\
#   [1em]
#   Tone Sentiment_{2}^2  &  &  -0.695  &  121.0  \\
#   &  &  (10.69)  &  (248.7)  \\
#   [1em]
#   Tone Sentiment_{2}^3  &  &  &  303.1  \\
#   &  &  &  (618.7)  \\
#   \hline
#   \(Number\;of\;obs.\)  &  40  &  40  &  40  \\
#   \hline
#   \end{tabular}

# %%
raw_table =\
r'''\begin{tabular}{l*{5}{c}}
\hline\hline
            &\multicolumn{1}{c}{MOEX}&\multicolumn{1}{c}{RTSI}&\multicolumn{1}{c}{FXGD\_ETF}&\multicolumn{1}{c}{RUCBITR}&\multicolumn{1}{c}{RUABITR}\\
\hline
Rate Change &       6.904         &       7.934         &      -12.47         &      -1.534\sym{**} &       1.673         \\
            &     (4.112)         &     (4.768)         &     (9.288)         &     (0.663)         &     (2.195)         \\
[1em]
Tone Sentiment\_{1}&       0.241\sym{**} &       0.138         &       0.135         &      0.0405         &      0.0732         \\
            &     (0.113)         &     (0.148)         &     (0.424)         &    (0.0265)         &    (0.0515)         \\
[1em]
Tone Sentiment\_{2}&      -0.248         &      -0.222         &      -0.249         &      -0.153         &      0.0448         \\
            &     (0.160)         &     (0.228)         &     (0.379)         &    (0.0915)         &     (0.114)         \\
[1em]
Rate Change##Tone Sentiment\_{1}&       0.109         &      -0.446         &      -1.125         &      -0.139\sym{*}  &       0.114         \\
            &     (0.302)         &     (0.412)         &     (1.010)         &    (0.0759)         &     (0.196)         \\
[1em]
Rate Change##Tone Sentiment\_{2}&       1.007\sym{**} &       2.132\sym{***}&      -0.179         &     0.00614         &       0.113         \\
            &     (0.460)         &     (0.543)         &     (0.489)         &    (0.0964)         &     (0.301)         \\
[1em]
Transparency&       0.137         &     -0.0255         &      -0.113         &      0.0689         &      0.0847         \\
            &     (0.170)         &     (0.222)         &     (0.370)         &    (0.0486)         &    (0.0870)         \\
[1em]
Trust       &      -2.008         &      -4.149         &      -3.050         &       0.560         &      -0.920         \\
            &     (2.992)         &     (4.537)         &     (7.919)         &     (0.668)         &     (1.287)         \\
\hline
\(N\)       &          40         &          40         &          40         &          40         &          40         \\
\hline\hline
\end{tabular}
}
{
\def\sym#1{\ifmmode^{#1}\else\(^{#1}\)\fi}
\begin{tabular}{l*{5}{c}}
\hline\hline
            &\multicolumn{1}{c}{RGBITR}&\multicolumn{1}{c}{RUGBITR1Y}&\multicolumn{1}{c}{RUGBITR3Y}&\multicolumn{1}{c}{RUGBITR5Y}&\multicolumn{1}{c}{RUGBITR10Y}\\
\hline
Rate Change &       0.797         &      -0.112         &       1.207         &       2.013         &       4.318         \\
            &     (1.625)         &     (0.414)         &     (1.444)         &     (2.278)         &     (3.637)         \\
[1em]
Tone Sentiment\_{1}&       0.124         &     0.00558         &      0.0493         &      0.0489         &       0.119         \\
            &    (0.0843)         &   (0.00744)         &    (0.0307)         &    (0.0469)         &    (0.0948)         \\
[1em]
Tone Sentiment\_{2}&      -0.218         &      0.0329         &     -0.0269         &       0.109         &      0.0337         \\
            &     (0.248)         &    (0.0252)         &    (0.0785)         &     (0.118)         &     (0.189)         \\
[1em]
Rate Change##Tone Sentiment\_{1}&       0.303         &     -0.0187         &      0.0382         &      0.0980         &       0.324         \\
            &     (0.185)         &    (0.0331)         &     (0.123)         &     (0.214)         &     (0.319)         \\
[1em]
Rate Change##Tone Sentiment\_{2}&      -0.330         &      0.0115         &       0.173         &       0.204         &       0.201         \\
            &     (0.215)         &    (0.0575)         &     (0.215)         &     (0.339)         &     (0.478)         \\
[1em]
Transparency&       0.216         &    -0.00872         &      0.0626         &       0.102         &       0.122         \\
            &     (0.140)         &    (0.0172)         &    (0.0606)         &    (0.0912)         &     (0.144)         \\
[1em]
Trust       &       1.441         &      -0.117         &      -0.374         &      -0.370         &      -2.185         \\
            &     (1.276)         &     (0.320)         &     (0.763)         &     (1.335)         &     (2.292)         \\
\hline
\(N\)       &          40         &          40         &          40         &          40         &          40         \\
\hline\hline
\multicolumn{6}{l}{\footnotesize Standard errors in parentheses}\\
\multicolumn{6}{l}{\footnotesize \sym{*} \(p<0.10\), \sym{**} \(p<0.05\), \sym{***} \(p<0.01\)}\\
\end{tabular}
'''
res = re.sub("[ ]+", "  ", raw_table)[:-1]
res = res.replace("  &  RUABITR  &  &  &  & ", 
                  "  & \multicolumn{5}{c}{RUABITR}")
res = res.replace("Tone  ", "Tone ")
res = res.replace("Rate  ", "Rate ")
res = res.replace("\(N\)", "\(Number\;of\;obs.\)")
res = res.replace("\hline\hline\n\\", "\hline\n\\")
res = res.replace("\\_", "_")
res = res.replace("\\multicolumn{6}{l}", "%\\multicolumn{6}{l}")
print(res)
# Out:
# \begin{tabular}{l*{5}{c}}
# \hline\hline
#   &\multicolumn{1}{c}{MOEX}&\multicolumn{1}{c}{RTSI}&\multicolumn{1}{c}{FXGD_ETF}&\multicolumn{1}{c}{RUCBITR}&\multicolumn{1}{c}{RUABITR}\\
# \hline
# Rate Change  &  6.904  &  7.934  &  -12.47  &  -1.534\sym{**}  &  1.673  \\
#   &  (4.112)  &  (4.768)  &  (9.288)  &  (0.663)  &  (2.195)  \\
# [1em]
# Tone Sentiment_{1}&  0.241\sym{**}  &  0.138  &  0.135  &  0.0405  &  0.0732  \\
#   &  (0.113)  &  (0.148)  &  (0.424)  &  (0.0265)  &  (0.0515)  \\
# [1em]
# Tone Sentiment_{2}&  -0.248  &  -0.222  &  -0.249  &  -0.153  &  0.0448  \\
#   &  (0.160)  &  (0.228)  &  (0.379)  &  (0.0915)  &  (0.114)  \\
# [1em]
# Rate Change##Tone Sentiment_{1}&  0.109  &  -0.446  &  -1.125  &  -0.139\sym{*}  &  0.114  \\
#   &  (0.302)  &  (0.412)  &  (1.010)  &  (0.0759)  &  (0.196)  \\
# [1em]
# Rate Change##Tone Sentiment_{2}&  1.007\sym{**}  &  2.132\sym{***}&  -0.179  &  0.00614  &  0.113  \\
# ...
